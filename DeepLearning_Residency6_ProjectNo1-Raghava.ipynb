# %% [markdown]
# The case study is from an open source dataset from Kaggle. Link to the Kaggle project site:
#
# https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling
#
# Given a Bank customer, can we build a classifier which can determine whether they will leave or not using Neural networks?
#
# Data file - bank.csv
#
# The points distribution for this case is as follows:
#
# Read the dataset Drop the columns which are unique for all users like IDs (2.5 points)
#
# Distinguish the feature and target set (2.5 points)
#
# Divide the data set into Train and test sets Normalize the train and test data (2.5 points)
#
# Initialize & build the model (10 points)
#
# Optimize the model (5 points)
#
# Predict the results using 0.5 as a threshold (5 points)
#
# Print the Accuracy score and confusion matrix (2.5 points)

# %% [markdown]
# # Richer syntax highlighting
#
# Improved support for nested languages:
#
# ```notebook-python
# df = pd.io.gbq.read_gbq('''
#   SELECT
#     REGEXP_EXTRACT(name, '[a-zA-Z]+'),
#     SUM(number) as count
#   FROM `bigquery-public-data.usa_names.usa_1910_2013`
#   WHERE state = 'TX'
#   GROUP BY name
#   ORDER BY count DESC
#   LIMIT 100
# ''')
# ```

# %%
import tensorflow as tf
tf.enable_eager_execution()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
tf.__version__
# Out:
# '1.15.0-rc3'

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/My Drive/Data/bank.csv')

# %%
data.drop(columns=['CustomerId', 'RowNumber', 'Surname'], inplace=True)

# %%
data.shape
# Out:
# (10000, 11)

# %%
data.head()
# Out:
#    CreditScore Geography  Gender  ...  IsActiveMember  EstimatedSalary  Exited
# 0          619    France  Female  ...               1        101348.88       1
# 1          608     Spain  Female  ...               1        112542.58       0
# 2          502    France  Female  ...               0        113931.57       1
# 3          699    France  Female  ...               0         93826.63       0
# 4          850     Spain  Female  ...               1         79084.10       0
#
# [5 rows x 11 columns]

# %% [markdown]
# **Distinguish the feature and target set!**

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['Exited'], axis=1)
y = data['Exited']

print (X.shape)
print (X.head())
# Out:
# (10000, 10)
#    CreditScore Geography  Gender  ...  HasCrCard  IsActiveMember  EstimatedSalary
# 0          619    France  Female  ...          1               1        101348.88
# 1          608     Spain  Female  ...          0               1        112542.58
# 2          502    France  Female  ...          1               0        113931.57
# 3          699    France  Female  ...          0               0         93826.63
# 4          850     Spain  Female  ...          1               1         79084.10
#
# [5 rows x 10 columns]

# %%
y = data.iloc[:, 10]
print (y.shape)
print (y.head())
# Out:
# (10000,)
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %% [markdown]
# **Divide the data set into Train and test sets Normalize the train and test data**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=1)

print ('X train', X_train.shape)
print ('X test', X_test.shape)
print ('y train', y_train.shape)
print ('y test', y_test.shape)
# Out:
# X train (7000, 10)
# X test (3000, 10)
# y train (7000,)
# y test (3000,)

# %%
X_train = pd.get_dummies(X_train)
X_train.shape
X_train.head()
# Out:
# (7000, 13)
#       CreditScore  Age  Tenure  ...  Geography_Spain  Gender_Female  Gender_Male
# 2228          644   37       8  ...                0              1            0
# 5910          481   39       6  ...                0              1            0
# 1950          680   37      10  ...                0              1            0
# 2119          690   29       5  ...                0              0            1
# 5947          656   45       7  ...                0              1            0
#
# [5 rows x 13 columns]

# %%
X_test = pd.get_dummies(X_test)

# %%
X_test.shape
X_test.head()
# Out:
# (3000, 13)
#       CreditScore  Age  Tenure  ...  Geography_Spain  Gender_Female  Gender_Male
# 9953          550   47       2  ...                0              0            1
# 3850          680   34       3  ...                0              0            1
# 4962          531   42       2  ...                0              1            0
# 3886          710   34       8  ...                0              0            1
# 5437          543   30       6  ...                0              0            1
#
# [5 rows x 13 columns]

# %%
from sklearn.preprocessing import Normalizer

# %%
transformer = Normalizer()
X_train = transformer.fit_transform(X_train)
X_test = transformer.fit_transform(X_test)

# %%
X_train.shape
X_train[0]
# Out:
# (7000, 13)
# array([3.06976548e-02, 1.76368513e-03, 3.81337326e-04, 0.00000000e+00,
#        9.53343316e-05, 4.76671658e-05, 0.00000000e+00, 9.99527079e-01,
#        4.76671658e-05, 0.00000000e+00, 0.00000000e+00, 4.76671658e-05,
#        0.00000000e+00])

# %%
y_test.shape
# y_test.head
# Out:
# (3000,)

# %%
import numpy as np

# %% [markdown]
# **Initialize & build the model**

# %%
#Initialize Sequential model
model = tf.keras.models.Sequential()

#Input data
model.add(tf.keras.layers.Reshape((13,),input_shape=(13,)))
#model.add(tf.keras.layers.Dense(13, input_shape=(13,)))
#Normalize the data
#model.add(tf.keras.layers.BatchNormalization())

#Add OUTPUT layer
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

#Comile the model
model.compile(optimizer='sgd', loss='mse', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 13)                182
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 13)                52
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 14
# =================================================================
# Total params: 248
# Trainable params: 222
# Non-trainable params: 26
# _________________________________________________________________

# %%
pd.Series.to_numpy (y_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#y_test = pd.get_dummies(y_test).values
y_test.shape
# Out:
# (3000,)

# %%
y_test.shape
# Out:
# (3000,)

# %%
#y_train = pd.get_dummies(y_train).values
y_test = pd.Series.to_numpy (y_test)
y_test
y_test[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])
# 0

# %%
#y_train = pd.get_dummies(y_train).values
y_train = pd.Series.to_numpy (y_train)
y_train
y_train[0]
# Out:
# array([0, 0, 1, ..., 1, 0, 1])
# 0

# %%
model.fit(X_train,y_train,          
          validation_data=(X_test,y_test),
          epochs=15)
# Out:
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/15
# 7000/7000 [==============================] - 1s 93us/sample - loss: 0.1990 - acc: 0.7977 - val_loss: 0.1874 - val_acc: 0.7903
# Epoch 2/15
# 7000/7000 [==============================] - 0s 54us/sample - loss: 0.1782 - acc: 0.7981 - val_loss: 0.1757 - val_acc: 0.7910
# Epoch 3/15
# 7000/7000 [==============================] - 1s 83us/sample - loss: 0.1698 - acc: 0.7986 - val_loss: 0.1707 - val_acc: 0.7910
# Epoch 4/15
# 7000/7000 [==============================] - 1s 81us/sample - loss: 0.1659 - acc: 0.7986 - val_loss: 0.1683 - val_acc: 0.7910
# Epoch 5/15
# 7000/7000 [==============================] - 1s 77us/sample - loss: 0.1639 - acc: 0.7986 - val_loss: 0.1671 - val_acc: 0.7910
# Epoch 6/15
# 7000/7000 [==============================] - 1s 76us/sample - loss: 0.1628 - acc: 0.7986 - val_loss: 0.1664 - val_acc: 0.7910
# Epoch 7/15
# 7000/7000 [==============================] - 1s 81us/sample - loss: 0.1621 - acc: 0.7986 - val_loss: 0.1660 - val_acc: 0.7910
# Epoch 8/15
# 7000/7000 [==============================] - 0s 67us/sample - loss: 0.1617 - acc: 0.7986 - val_loss: 0.1658 - val_acc: 0.7910
# Epoch 9/15
# 7000/7000 [==============================] - 0s 58us/sample - loss: 0.1614 - acc: 0.7986 - val_loss: 0.1656 - val_acc: 0.7910
# Epoch 10/15
# 7000/7000 [==============================] - 0s 55us/sample - loss: 0.1612 - acc: 0.7986 - val_loss: 0.1655 - val_acc: 0.7910
# Epoch 11/15
# 7000/7000 [==============================] - 0s 55us/sample - loss: 0.1611 - acc: 0.7986 - val_loss: 0.1655 - val_acc: 0.7910
# Epoch 12/15
# 7000/7000 [==============================] - 0s 53us/sample - loss: 0.1610 - acc: 0.7986 - val_loss: 0.1654 - val_acc: 0.7910
# Epoch 13/15
# 7000/7000 [==============================] - 0s 60us/sample - loss: 0.1609 - acc: 0.7986 - val_loss: 0.1654 - val_acc: 0.7910
# Epoch 14/15
# 7000/7000 [==============================] - 1s 79us/sample - loss: 0.1608 - acc: 0.7986 - val_loss: 0.1653 - val_acc: 0.7910
# Epoch 15/15
# 7000/7000 [==============================] - 0s 64us/sample - loss: 0.1607 - acc: 0.7986 - val_loss: 0.1653 - val_acc: 0.7910

# %% [markdown]
# # **Predict the results using 0.5 as a threshold (5 points) !**

# %%
pred = model.predict(X_test)

# %%
pred
# Out:
# array([[0.1980516 ],
#        [0.2223061 ],
#        [0.19806167],
#        ...,
#        [0.2434839 ],
#        [0.18918967],
#        [0.18953416]], dtype=float32)

# %%
y_pred = (pred > 0.5)

# %%
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %% [markdown]
# ### **Print the Accuracy score and confusion matrix (2.5 points)**

# %%
model.evaluate(X_test, y_test, verbose=0)[1]
# Out:
# 0.791

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[2373,    0],
#        [ 627,    0]])

# %% [markdown]
# **Optimize the Model**

# %%
#Initialize Sequential model
model = tf.keras.models.Sequential()

#Input data
model.add(tf.keras.layers.Reshape((13,),input_shape=(13,)))

#Normalize the data
model.add(tf.keras.layers.BatchNormalization())

#Add 1st hidden layer
model.add(tf.keras.layers.Dense(10, activation='sigmoid'))

#Add 2nd hidden layer
model.add(tf.keras.layers.Dense(8, activation='sigmoid'))

#Add OUTPUT layer
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# %%
sgd_optimizer = tf.keras.optimizers.SGD(lr=0.03)

#Comile the model
model.compile(optimizer=sgd_optimizer, loss='mse', metrics=['accuracy'])

# %%
model.fit(X_train,y_train,          
          validation_data=(X_test,y_test),
          epochs=15)
# Out:
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/15
# 7000/7000 [==============================] - 1s 121us/sample - loss: 0.1723 - acc: 0.7986 - val_loss: 0.1656 - val_acc: 0.7910
# Epoch 2/15
# 7000/7000 [==============================] - 0s 60us/sample - loss: 0.1608 - acc: 0.7986 - val_loss: 0.1650 - val_acc: 0.7910
# Epoch 3/15
# 7000/7000 [==============================] - 0s 60us/sample - loss: 0.1605 - acc: 0.7986 - val_loss: 0.1650 - val_acc: 0.7910
# Epoch 4/15
# 7000/7000 [==============================] - 0s 61us/sample - loss: 0.1604 - acc: 0.7986 - val_loss: 0.1649 - val_acc: 0.7910
# Epoch 5/15
# 7000/7000 [==============================] - 0s 65us/sample - loss: 0.1604 - acc: 0.7986 - val_loss: 0.1649 - val_acc: 0.7910
# Epoch 6/15
# 7000/7000 [==============================] - 0s 67us/sample - loss: 0.1604 - acc: 0.7986 - val_loss: 0.1649 - val_acc: 0.7910
# Epoch 7/15
# 7000/7000 [==============================] - 1s 94us/sample - loss: 0.1603 - acc: 0.7986 - val_loss: 0.1649 - val_acc: 0.7910
# Epoch 8/15
# 7000/7000 [==============================] - 1s 97us/sample - loss: 0.1603 - acc: 0.7986 - val_loss: 0.1649 - val_acc: 0.7910
# Epoch 9/15
# 7000/7000 [==============================] - 1s 85us/sample - loss: 0.1603 - acc: 0.7986 - val_loss: 0.1649 - val_acc: 0.7910
# Epoch 10/15
# 7000/7000 [==============================] - 0s 60us/sample - loss: 0.1602 - acc: 0.7986 - val_loss: 0.1648 - val_acc: 0.7910
# Epoch 11/15
# 7000/7000 [==============================] - 0s 60us/sample - loss: 0.1602 - acc: 0.7986 - val_loss: 0.1648 - val_acc: 0.7910
# Epoch 12/15
# 7000/7000 [==============================] - 0s 59us/sample - loss: 0.1602 - acc: 0.7986 - val_loss: 0.1648 - val_acc: 0.7910
# Epoch 13/15
# 7000/7000 [==============================] - 0s 59us/sample - loss: 0.1602 - acc: 0.7986 - val_loss: 0.1648 - val_acc: 0.7910
# Epoch 14/15
# 7000/7000 [==============================] - 0s 62us/sample - loss: 0.1602 - acc: 0.7986 - val_loss: 0.1647 - val_acc: 0.7910
# Epoch 15/15
# 7000/7000 [==============================] - 0s 59us/sample - loss: 0.1601 - acc: 0.7986 - val_loss: 0.1647 - val_acc: 0.7910

# %%
model.evaluate(X_test, y_test, verbose=0)[1]
# Out:
# 0.791

# %% [markdown]
# **With additional optimization also, the accuracy is same**
